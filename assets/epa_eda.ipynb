# %%
import pandas as pd
import seaborn as sns
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## example
# data = (r"C:\Users\USERNAME\Coding\epa-aqs-project\air_quality_data.json")

# %%
# enter path of the dataset to explore
data = (r"ENTER_PATH_HERE")

# %%
def load_json_to_dataframe(filename="air_quality_data.json", record_path=None):
    """Load JSON data from a file into a Pandas DataFrame."""
    with open(filename, "r") as file:
        data = json.load(file)
    return pd.json_normalize(data, record_path=record_path)

# %%
df = load_json_to_dataframe(data, record_path="Data")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state_code                   54 non-null     object
#  1   county_code                  54 non-null     object
#  2   site_number                  54 non-null     object
#  3   parameter_code               54 non-null     object
#  4   poc                          54 non-null     int64
#  5   latitude                     54 non-null     float64
#  6   longitude                    54 non-null     float64
#  7   datum                        54 non-null     object
#  8   parameter                    54 non-null     object
#  9   sample_duration_code         54 non-null     object
#  10  sample_duration              54 non-null     object
#  11  pollutant_standard           48 non-null     object
#  12  metric_used                  54 non-null     object
# ...

# %%
plt.figure(figsize=(10,8)) # Adjust width and height as needed
sns.heatmap(df.corr())
plt.show() # Display the plot
